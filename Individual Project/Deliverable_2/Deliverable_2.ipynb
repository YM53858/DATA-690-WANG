# %% [markdown]
# <a href="https://colab.research.google.com/github/YM53858/DATA-690-WANG/blob/master/Individual%20Project/Deliverable_2/Deliverable_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Deliverable #2 -

# %% [markdown]
# ### Data Source:
# Reading stock data from Yahoo using Yahoo Finance API. For this we have to use a python library called **yfinance** .Yahoo Finance API provides access to more than five years of daily OHLC price data. Also, you can get minutes OHLC data for recent days.Using the Yahoo API (without authentication), you are limited to 2,000 requests per hour per IP or up to a total of 48,000 requests a day.

# %%
import yfinance as yf

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from datetime import datetime

# %% [markdown]
# Firstly we will be requesting stock information with yfinance, and handle that data by creating data  frames using pandas .

# %%
my_stock_list = ['TSLA', 'ORTX', 'CYTK', 'AAPL']

for stock in my_stock_list:
    globals()[stock] = yf.Ticker(stock).history(period="1y") # 1 year data till current date

# %%
company_list = [TSLA, ORTX, CYTK, AAPL]
company_name = ["TESLA", "ORCHARD THERAPEUTICS", "CYTOKINETICS", "APPLE"]

for company, com_name in zip(company_list, company_name):
    company["company_name"] = com_name
    
df = pd.concat(company_list, axis=0)
df.head(5)
# Out:
#                  Open       High        Low      Close     Volume  Dividends  \
# Date
# 2019-10-24  59.674000  60.986000  57.840000  59.936001  148604500        0.0
# 2019-10-25  59.543999  66.000000  59.222000  65.625999  150030500        0.0
# 2019-10-28  65.508003  68.167999  64.519997  65.542000   94351500        0.0
# 2019-10-29  63.998001  64.860001  62.950001  63.243999   63421500        0.0
# 2019-10-30  62.599998  63.757999  61.993999  63.001999   48209000        0.0
#
#             Stock Splits company_name
# Date
# 2019-10-24           0.0        TESLA
# 2019-10-25           0.0        TESLA
# 2019-10-28           0.0        TESLA
# 2019-10-29           0.0        TESLA
# 2019-10-30           0.0        TESLA

# %%
ORTX['Close'].plot()

# %% [markdown]
# ### What was the change in price of a specific stock over time of 1 year?

# %%
for company in company_list:
    company[['Close']].plot(figsize=(10,5)).set_title(str(company["company_name"][0])) # plotting closing price of each company over the time of one year

# %% [markdown]
# ### What was the moving average of above listed stocks?

# %%
ma_period = [30, 90, 120]

for period in ma_period:
    for company in company_list:
        new_column = "MA for " + str(period) + " days" 
        company[new_column] = company['Close'].rolling(period).mean() # calculating moving average

# %%
for company in company_list:
    company[["Close","MA for 30 days","MA for 90 days","MA for 120 days"]].plot(figsize=(10,5)).set_title(str(company["company_name"][0]))

# %% [markdown]
# ## To be continued...
